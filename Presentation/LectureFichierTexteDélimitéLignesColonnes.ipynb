# %%
import os, re, pandas as pd

# %%
# !dir   ..\donnees\synop.202309.test.csv
# Out:
#  Le volume dans le lecteur F s'appelle Data
#  Le num‚ro de s‚rie du volume est D4F7-8E12
#
#  R‚pertoire de F:\PythonFormation\donnees
#
# 01/12/2023  14:43               324 synop.202309.test.csv
#                1 fichier(s)              324 octets
#                0 R‚p(s)  144ÿ911ÿ728ÿ640 octets libres

# %% [markdown]
# # Décorateur temps d'exécution

# %%
import time

def tempsExecution(func):
    def chronometrerExécution(*_args, **_kwargs): 
        t0 = time.perf_counter()
        result = func(*_args, **_kwargs) 
        elapsed = time.perf_counter() - t0
        name = func.__name__
        args = ', '.join(repr(arg) for arg in _args) \
               if len(_args) == 1 \
               else ', '.join(arg+'='+repr(_kwargs[arg]) for arg in _kwargs)
        print(f'exécution {elapsed:0.8f}s\nfonction {name}({args})')
        return result
    return chronometrerExécution

# %% [markdown]
# # Lecture fichier et création du dictionnaire

# %%
class oIndexColonnes(dict): 
    def __new__(*args, **kwargs):
        new_dict = dict.__new__(*args, **kwargs)
        return new_dict
    
    def getColumn(self, index ):
        list = self.get(index)
        return None if list is None else [i[0] for i in self[index]]

    def getColumns(self):
        return { colonne:self.getColumn(colonne) for colonne in self}

# %%
class oIndexLignes(dict): 
    def __new__(*args, **kwargs):
        new_dict = dict.__new__(*args, **kwargs)
        return new_dict
    
    def getValeur(self, ligne, index ):
        return self[ligne][index] if self[ligne][index][0] != 'mq' else [None]

    def getValeurLigneCle(self, ligne, index ):
        return self[ligne][index][0]

# %%
# !dir ..\donnees\synop.202309.csv
# Out:
#  Le volume dans le lecteur F s'appelle Data
#  Le num‚ro de s‚rie du volume est D4F7-8E12
#
#  R‚pertoire de F:\PythonFormation\donnees
#
# 29/11/2023  21:49         4ÿ069ÿ470 synop.202309.csv
#                1 fichier(s)        4ÿ069ÿ470 octets
#                0 R‚p(s)  144ÿ911ÿ728ÿ640 octets libres

# %%
@tempsExecution
def lectureFichier(nom='..\donnees\synop.202309.csv',
                   caractere=';'):
    indexLigne,indexLignes=0,oIndexLignes()
    with open(nom,'r') as fichier :
        colonnes=fichier.readline().replace('\n','').split(caractere)
        while '' in colonnes : colonnes.pop()
        dictionnaire = oIndexColonnes({ cle:list() for cle in colonnes})
        ligne =fichier.readline()
        while ligne :
            ligne =ligne.split(caractere)[:len(colonnes)]
            indexLignes[indexLigne]={ cle:[ligne[i]] for i,cle in enumerate(colonnes) }
            _=[dictionnaire[cle].append(indexLignes.getValeur(indexLigne,cle)) for i,cle in enumerate(dictionnaire)]
            ligne =fichier.readline(); 
            indexLigne += 1
    return dictionnaire,indexLignes

# %%
dictionnaire,indexLignes=lectureFichier()
# Out:
# exécution 1.41438060s
# fonction lectureFichier()

# %%
dictionnaire
# Out:
# {'numer_sta': [['07005'],
#   ['07015'],
#   ['07020'],
#   ['07027'],
#   ['07037'],
#   ['07072'],
#   ['07110'],
#   ['07117'],
#   ['07130'],
#   ['07139'],
#   ['07149'],
#   ['07168'],
#   ['07181'],
#   ['07190'],
#   ['07207'],
#   ['07222'],
#   ['07240'],
#   ['07255'],
#   ['07280'],
#   ['07299'],
#   ['07314'],
#   ['07335'],
#   ['07434'],
#   ['07460'],
#   ['07471'],
#   ['07481'],
#   ['07510'],
#   ['07535'],
#   ['07558'],
#   ['07577'],
#   ['07591'],
#   ['07607'],
#   ['07621'],
#   ['07627'],
#   ['07630'],
#   ['07643'],
#   ['07650'],
#   ['07661'],
#   ['07690'],
#   ['07747'],
#   ['07761'],
#   ['07790'],
#   ['61968'],
#   ['61970'],
#   ['61972'],
#   ['61976'],
#   ['61980'],
#   ['61996'],
#   ['61997'],
#   ['61998'],
#   ['67005'],
#   ['71805'],
#   ['78890'],
#   ['78894'],
#   ['78897'],
#   ['78922'],
#   ['78925'],
#   ['81405'],
#   ['81408'],
#   ['81415'],
#   ['07005'],
#   ['07015'],
#   ['07020'],
#   ['07027'],
#   ['07037'],
# ...

# %%
dictionnaire.getColumn('numer_sta')
# Out:
# ['07005',
#  '07015',
#  '07020',
#  '07027',
#  '07037',
#  '07072',
#  '07110',
#  '07117',
#  '07130',
#  '07139',
#  '07149',
#  '07168',
#  '07181',
#  '07190',
#  '07207',
#  '07222',
#  '07240',
#  '07255',
#  '07280',
#  '07299',
#  '07314',
#  '07335',
#  '07434',
#  '07460',
#  '07471',
#  '07481',
#  '07510',
#  '07535',
#  '07558',
#  '07577',
#  '07591',
#  '07607',
#  '07621',
#  '07627',
#  '07630',
#  '07643',
#  '07650',
#  '07661',
#  '07690',
#  '07747',
#  '07761',
#  '07790',
#  '61968',
#  '61970',
#  '61972',
#  '61976',
#  '61980',
#  '61996',
#  '61997',
#  '61998',
#  '67005',
#  '71805',
#  '78890',
#  '78894',
#  '78897',
#  '78922',
#  '78925',
#  '81405',
#  '81408',
#  '81415',
#  '07005',
#  '07015',
#  '07020',
#  '07027',
#  '07037',
#  '07072',
#  '07110',
#  '07117',
#  '07130',
#  '07139',
#  '07149',
#  '07168',
#  '07181',
#  '07190',
#  '07207',
#  '07222',
#  '07240',
#  '07255',
#  '07280',
#  '07299',
#  '07314',
#  '07335',
#  '07434',
# ...

# %%
dictionnaire.getColumns()
# Out:
# {'numer_sta': ['07005',
#   '07015',
#   '07020',
#   '07027',
#   '07037',
#   '07072',
#   '07110',
#   '07117',
#   '07130',
#   '07139',
#   '07149',
#   '07168',
#   '07181',
#   '07190',
#   '07207',
#   '07222',
#   '07240',
#   '07255',
#   '07280',
#   '07299',
#   '07314',
#   '07335',
#   '07434',
#   '07460',
#   '07471',
#   '07481',
#   '07510',
#   '07535',
#   '07558',
#   '07577',
#   '07591',
#   '07607',
#   '07621',
#   '07627',
#   '07630',
#   '07643',
#   '07650',
#   '07661',
#   '07690',
#   '07747',
#   '07761',
#   '07790',
#   '61968',
#   '61970',
#   '61972',
#   '61976',
#   '61980',
#   '61996',
#   '61997',
#   '61998',
#   '67005',
#   '71805',
#   '78890',
#   '78894',
#   '78897',
#   '78922',
#   '78925',
#   '81405',
#   '81408',
#   '81415',
#   '07005',
#   '07015',
#   '07020',
#   '07027',
#   '07037',
#   '07072',
#   '07110',
#   '07117',
#   '07130',
#   '07139',
#   '07149',
#   '07168',
#   '07181',
#   '07190',
#   '07207',
# ...

# %%
indexLignes[0]
# Out:
# {'numer_sta': ['07005'],
#  'date': ['20230901000000'],
#  'pmer': ['101120'],
#  'tend': ['10'],
#  'cod_tend': ['2'],
#  'dd': ['230'],
#  'ff': ['1.700000'],
#  't': ['290.550000'],
#  'td': ['290.050000'],
#  'u': ['97'],
#  'vv': ['5510'],
#  'ww': ['60'],
#  'w1': ['mq'],
#  'w2': ['mq'],
#  'n': ['mq'],
#  'nbas': ['mq'],
#  'hbas': ['mq'],
#  'cl': ['mq'],
#  'cm': ['mq'],
#  'ch': ['mq'],
#  'pres': ['100270'],
#  'niv_bar': ['mq'],
#  'geop': ['mq'],
#  'tend24': ['20'],
#  'tn12': ['mq'],
#  'tn24': ['mq'],
#  'tx12': ['mq'],
#  'tx24': ['mq'],
#  'tminsol': ['289.550000'],
#  'sw': ['mq'],
#  'tw': ['mq'],
#  'raf10': ['4.000000'],
#  'rafper': ['6.800000'],
#  'per': ['-10'],
#  'etat_sol': ['mq'],
#  'ht_neige': ['0.000000'],
#  'ssfrai': ['mq'],
#  'perssfrai': ['mq'],
#  'rr1': ['0.400000'],
#  'rr3': ['0.800000'],
#  'rr6': ['2.000000'],
#  'rr12': ['12.300000'],
#  'rr24': ['12.300000'],
#  'phenspe1': ['mq'],
#  'phenspe2': ['mq'],
#  'phenspe3': ['mq'],
# ...

# %%
indexLignes.getValeurLigneCle(0,'numer_sta')
# Out:
# '07005'

# %%
indexLignes.getValeur(0,'numer_sta')
# Out:
# ['07005']

# %%
@tempsExecution
def initTypeColones(dictionnaire)-> (dict,dict):
    dictionnaire = {colonne:
                     [int(i) for i in dictionnaire[colonne]]
                     if sum([str(i).isdecimal() for i in dictionnaire[colonne]]) == len(dictionnaire[colonne]) 
                     else [float(i) if i is not None else None for i in dictionnaire[colonne]] 
                            if sum([re.sub('[+-\.]','',str(i), count=1).isdecimal() or (i is None) for i in dictionnaire[colonne]]) 
                                   == len(dictionnaire[colonne]) 
                            else dictionnaire[colonne]
                 for colonne in dictionnaire }
    dictionnaire_info = { colonne:type(dictionnaire[colonne][0]) for colonne in dictionnaire}
    return dictionnaire, dictionnaire_info

# %%
dictionnaire1, dictionnaire1_info = initTypeColones(dictionnaire.getColumns())
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
dictionnaire1_info
# Out:
# {'numer_sta': int,
#  'date': int,
#  'pmer': float,
#  'tend': float,
#  'cod_tend': float,
#  'dd': float,
#  'ff': float,
#  't': float,
#  'td': float,
#  'u': float,
#  'vv': float,
#  'ww': float,
#  'w1': NoneType,
#  'w2': NoneType,
#  'n': NoneType,
#  'nbas': NoneType,
#  'hbas': NoneType,
#  'cl': NoneType,
#  'cm': NoneType,
#  'ch': NoneType,
#  'pres': float,
#  'niv_bar': NoneType,
#  'geop': NoneType,
#  'tend24': float,
#  'tn12': NoneType,
#  'tn24': NoneType,
#  'tx12': NoneType,
#  'tx24': NoneType,
#  'tminsol': float,
#  'sw': NoneType,
#  'tw': NoneType,
#  'raf10': float,
#  'rafper': float,
#  'per': float,
#  'etat_sol': NoneType,
#  'ht_neige': float,
#  'ssfrai': NoneType,
#  'perssfrai': NoneType,
#  'rr1': str,
#  'rr3': str,
#  'rr6': str,
#  'rr12': str,
#  'rr24': str,
#  'phenspe1': NoneType,
#  'phenspe2': NoneType,
#  'phenspe3': NoneType,
#  'phenspe4': NoneType,
#  'nnuage1': NoneType,
#  'ctype1': NoneType,
#  'hnuage1': NoneType,
# ...
